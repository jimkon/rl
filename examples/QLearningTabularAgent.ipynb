# %%
from mountain_car_stds import *
import rl_lib
from rl_lib.agents.q_learning import TabularQLearningAgent

class MCAgent(TabularQLearningAgent):

    def __init__(self, bins_per_dim=2, epsilon_factor=1):
        super().__init__(state_low, state_high, actions_num, bins_per_dim=bins_per_dim,
                         epsilon_factor=epsilon_factor)
        
agent = MCAgent(bins_per_dim=10)

# %%
df = run(agent, 3000)
# Out:
# Episode 0 finished after 200 steps with total reward -267.0 in  19.0 ms (0.09 per step)
# Episode 1 finished after 200 steps with total reward -246.0 in  16.9 ms (0.08 per step)
# Episode 2 finished after 200 steps with total reward -264.3 in  17.0 ms (0.08 per step)
# Episode 3 finished after 200 steps with total reward -266.3 in  18.9 ms (0.09 per step)
# Episode 4 finished after 200 steps with total reward -261.0 in  18.9 ms (0.09 per step)
# Episode 5 finished after 200 steps with total reward -235.7 in  19.0 ms (0.09 per step)
# Episode 6 finished after 200 steps with total reward -256.1 in  18.9 ms (0.09 per step)
# Episode 7 finished after 200 steps with total reward -233.4 in  19.0 ms (0.09 per step)
# Episode 8 finished after 200 steps with total reward -229.4 in  18.9 ms (0.09 per step)
# Episode 9 finished after 200 steps with total reward -216.6 in  18.0 ms (0.09 per step)
# Episode 10 finished after 200 steps with total reward -213.1 in  18.0 ms (0.09 per step)
# ...

# %%
show_episode(df, episode=-1)

# %%
show_Q(agent)

# %%
show_progress(df, agent)
