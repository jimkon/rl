# %%
from mountain_car_stds import *
import matplotlib.pyplot as plt
import rl_lib
from rl_lib.agents.q_learning import RBFQLearningAgent, QLearningAgent


class MCAgent(RBFQLearningAgent):

    def __init__(self):
        samplers = 2000
        super().__init__(state_dims=2, actions_num=3, samplers=samplers,
                         constant_samplers=True, mapper=rl_lib.utils.UnitMapper(state_low, state_high),
                         constant_gammas=True,
                         epsilon_factor=1)
        
agent = MCAgent()
agent.plot_samplers()
# Out:
# RBF net init in(2) samplers(2000) out(1)
# RBF net init in(2) samplers(2000) out(1)
# RBF net init in(2) samplers(2000) out(1)

# %%
show_Q(agent)

# %%
df = run(agent, 300, verbose=1)
# Out:
# Run 300 episodes in 80.15 seconds. Average reward -147.69836579253112

# %%
agent.plot_samplers()

# %%
show_Q(agent)

# %%
show_episode(df)

# %%
show_progress(df, agent)
